# %% [markdown]
# # A Guided Tour of LSST Processed Visit Images (calexp)
# <br>Author(s): **David Shupe** ([@stargaser](https://github.com/LSSTScienceCollaborations/StackClub/issues/new?body=@stargaser))
# <br>Maintainer(s): **Douglas Tucker** ([@douglasleetucker](https://github.com/LSSTScienceCollaborations/StackClub/issues/new?body=@douglasleetucker))
# <br>Level: **Introductory**
# <br>Last Verified to Run: **2021-09-11**
# <br>Verified Stack Release: **w_2021_33**

# %% [markdown]
# ### Learning Objectives:
#
# This notebook investigates LSST stack processed visit images, conventionally referred to as `calexp` objects. The `calexp` is a Butler dataset type that corresponds to a single processed, calibrated, and characterized CCD and the metadata associated with that image (mask plane, psf, etc.). We will explore the content of the `calexp` object and then compare to coadd images.
#
# After working through this tutorial you should be able to:
# 1. Investigate the content of a calexp (and to some extent, other Stack objects).
# 2. Follow some best practices when working with `calexp` objects.
#
# ### Logistics
# This notebook is intended to be run at `lsst-lsp-stable.ncsa.illinois.edu` or `data.lsst.cloud` from a local git clone of the [StackClub](https://github.com/LSSTScienceCollaborations/StackClub) repo.
#
# ### Setup

# %%
# Site, host, and stack version
! echo $EXTERNAL_INSTANCE_URL
! echo $HOSTNAME
! eups list -s | grep lsst_distrib
# Out:
# https://data.lsst.cloud
# nb-luiseduardocantero
# lsst_distrib          g0b29ad24fb+9b30730ed8 	w_2022_40 current setup

# %%
# General imports
import os
from pprint import pprint
import matplotlib.pyplot as plt

# %%
# Stack imports
import lsst.daf.butler   as dafButler        #load the Butler to access data 
import lsst.afw.display  as afwDisplay       #load lsst.afw.display to gain access to image visualization routines.  
afwDisplay.setDefaultBackend('matplotlib')   #set the default display backend to matplotlib

# %% [markdown]
# ## Retrieving and inspecting images

# %% [markdown]
# We will be using the DESC DC2 Run2.2i data set (which comprises a simulated 300 sq deg patch of 5 years of Rubin LSST WFD data). Here, we create a Butler for the data set we wish to examine and grab the calexp image we are interested in exploring. More information on the Butler can be found in other Stack Club tutorials.
#
# In the first part of the tutorial, we will examine the calibrated exposure (`calexp`) for a single `visit`.  In the second part of the tutorial we will examine the calibrated image for a coadd `patch`. In the following cell, we grab both of these data objects.

# %%
# Location of the DC2 Gen3 repository on this site
URL = os.getenv('EXTERNAL_INSTANCE_URL')
if URL.endswith('data.lsst.cloud'): # IDF
    repo = "s3://butler-us-central1-dp01"
elif URL.endswith('ncsa.illinois.edu'): # NCSA
    repo = "/repo/dc2"
else:
    raise Exception(f"Unrecognized URL: {URL}")

collection='2.2i/runs/DP0.1'

# Create the butler
butler = dafButler.Butler(repo,collections=collection)
registry = butler.registry        

# Grab a calexp of interest
dataId = {'visit': '512055', 'detector': 76, 'band':'i'}
calexp = butler.get('calexp', **dataId)

## Grab a deepCoadd tract and patch
coadd_dataId = {'band':'i', 'skymap': 'DC2', 'tract': 4851, 'patch': 29}
coadd = butler.get('deepCoadd', **coadd_dataId)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [76], in <cell line: 18>()
#      16 # Grab a calexp of interest
#      17 dataId = {'visit': '1', 'detector': 76, 'band':'i'}
# ---> 18 calexp = butler.get('calexp', **dataId)
#      20 ## Grab a deepCoadd tract and patch
#      21 coadd_dataId = {'band':'i', 'skymap': 'DC2', 'tract': 4851, 'patch': 29}
#
# File /opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-4.1.0/Linux64/daf_butler/g35a551b10e+17c7ad0751/python/lsst/daf/butler/_butler.py:1387, in Butler.get(self, datasetRefOrType, dataId, parameters, collections, **kwargs)
#    1338 """Retrieve a stored dataset.
#    1339
#    1340 Parameters
#    (...)
#    1384 ``exposure`` is a temporal dimension.
#    1385 """
#    1386 log.debug("Butler get: %s, dataId=%s, parameters=%s", datasetRefOrType, dataId, parameters)
# -> 1387 ref = self._findDatasetRef(datasetRefOrType, dataId, collections=collections, **kwargs)
#    1388 return self.getDirect(ref, parameters=parameters)
#
# File /opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-4.1.0/Linux64/daf_butler/g35a551b10e+17c7ad0751/python/lsst/daf/butler/_butler.py:1073, in Butler._findDatasetRef(self, datasetRefOrType, dataId, collections, allowUnresolved, **kwargs)
#    1070     idNumber = None
#    1071 timespan: Optional[Timespan] = None
# -> 1073 dataId, kwargs = self._rewrite_data_id(dataId, datasetType, **kwargs)
#    1075 if datasetType.isCalibration():
#    1076     # Because this is a calibration dataset, first try to make a
#    1077     # standardize the data ID without restricting the dimensions to
#    1078     # those of the dataset type requested, because there may be extra
#    1079     # dimensions that provide temporal information for a validity-range
#    1080     # lookup.
#    1081     dataId = DataCoordinate.standardize(
#    1082         dataId, universe=self.registry.dimensions, defaults=self.registry.defaults.dataId, **kwargs
#    1083     )
#
# File /opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-4.1.0/Linux64/daf_butler/g35a551b10e+17c7ad0751/python/lsst/daf/butler/_butler.py:1003, in Butler._rewrite_data_id(self, dataId, datasetType, **kwargs)
#     997             raise ValueError(
#     998                 f"DataId specification for dimension {dimensionName} is not"
#     999                 f" uniquely constrained to a single dataset by {values}."
#    1000                 f" Got {len(records)} results."
#    1001             )
#    1002     else:
# -> 1003         raise ValueError(
#    1004             f"DataId specification for dimension {dimensionName} matched no"
#    1005             f" records when constrained by {values}"
#    1006         )
#    1008 # Get the primary key from the real dimension object
#    1009 dimension = self.registry.dimensions.getStaticDimensions()[dimensionName]
#
# ValueError: DataId specification for dimension visit matched no records when constrained by {'name': '1'}

# %% [markdown]
# ## Image planes / pixel data

# %% [markdown]
# In terms of pixel data, a calexp contains an image, a mask, and a variance.
#
# Let's see how to access the image.

# %%
calexp.image
# Out:
# lsst.afw.image.image.ImageF=[[-3.82834053e+01  3.42491035e+01  6.89195404e+01 ...  1.07490247e+03
#    1.04379651e+03  6.83699646e+02]
#  [-1.53812799e+01  6.62068939e+01  1.01078018e+02 ...  2.17995459e+03
#    1.68644275e+03  1.12186377e+03]
#  [ 1.56634842e+02  5.89559097e+01  4.05811920e+01 ...  4.90955322e+03
#    3.62566113e+03  2.37405029e+03]
#  ...
#  [ 1.14947586e+02  1.90423889e+02  3.01270084e+01 ...  1.50209183e+02
#   -8.01385345e+01 -5.34359436e+01]
#  [ 9.62147808e+00 -2.51698074e+01 -8.81778793e+01 ...  5.51945419e+01
#    3.44382763e-01  1.23965187e+02]
#  [ 2.03337059e+01  4.38427010e+01  6.95885391e+01 ...  9.42831573e+01
#   -1.12728176e+01 -8.36537323e+01]], bbox=(minimum=(0, 0), maximum=(4071, 3999))

# %% [markdown]
# The `calexp.image` is a Stack object of type `ImageF` (an image with floating point values).

# %% [markdown]
# The `calexp.image` object can be displayed directly using other tools in the LSST Stack. To show the pixel data, we will make use of the matplotlib backend to `lsst.afw.display`.
#
# Due to current limitations of this backend, the display must be defined and used in the same code cell, much as matplotlib commands in a notebook must all be in one cell to produce a plot.

# %%
# %matplotlib inline

# %% [markdown]
# If the entire calexp is displayed, masks will be overlaid. Here we will eschew the mask display by showing only the image.

# %%
display = afwDisplay.Display()
display.scale("asinh", "zscale")
display.mtv(calexp.image)

# %% [markdown]
# We can also access the low-level pixel values as a `numpy` array, using the `.array` attribute.

# %%
data = calexp.image.array
data
# Out:
# array([[-3.82834053e+01,  3.42491035e+01,  6.89195404e+01, ...,
#          1.07490247e+03,  1.04379651e+03,  6.83699646e+02],
#        [-1.53812799e+01,  6.62068939e+01,  1.01078018e+02, ...,
#          2.17995459e+03,  1.68644275e+03,  1.12186377e+03],
#        [ 1.56634842e+02,  5.89559097e+01,  4.05811920e+01, ...,
#          4.90955322e+03,  3.62566113e+03,  2.37405029e+03],
#        ...,
#        [ 1.14947586e+02,  1.90423889e+02,  3.01270084e+01, ...,
#          1.50209183e+02, -8.01385345e+01, -5.34359436e+01],
#        [ 9.62147808e+00, -2.51698074e+01, -8.81778793e+01, ...,
#          5.51945419e+01,  3.44382763e-01,  1.23965187e+02],
#        [ 2.03337059e+01,  4.38427010e+01,  6.95885391e+01, ...,
#          9.42831573e+01, -1.12728176e+01, -8.36537323e+01]], dtype=float32)

# %%
data.__class__
# Out:
# numpy.ndarray

# %% [markdown]
# Let's list all the methods for our calexp.

# %%
calexp_methods = [m for m in dir(calexp) if not m.startswith('_')]

# %%
calexp_methods
# Out:
# ['Factory',
#  'clone',
#  'containsSkyCoords',
#  'convertD',
#  'convertF',
#  'convex_polygon',
#  'detector',
#  'dtype',
#  'filter',
#  'filterLabel',
#  'getBBox',
#  'getConvexPolygon',
#  'getCutout',
#  'getDetector',
#  'getDimensions',
#  'getFilter',
#  'getFilterLabel',
#  'getHeight',
#  'getImage',
#  'getInfo',
#  'getMask',
#  'getMaskedImage',
#  'getMetadata',
#  'getPhotoCalib',
#  'getPsf',
#  'getVariance',
#  'getWcs',
#  'getWidth',
#  'getX0',
#  'getXY0',
#  'getY0',
#  'hasPsf',
#  'hasWcs',
#  'height',
#  'image',
#  'info',
#  'mask',
#  'maskedImage',
#  'photoCalib',
#  'psf',
#  'readFits',
#  'readFitsWithOptions',
#  'setDetector',
#  'setFilter',
#  'setFilterLabel',
#  'setImage',
#  'setInfo',
#  'setMask',
#  'setMaskedImage',
#  'setMetadata',
#  'setPhotoCalib',
#  'setPsf',
#  'setVariance',
#  'setWcs',
#  'setXY0',
#  'subset',
#  'variance',
#  'visitInfo',
#  'wcs',
#  'width',
#  'writeFits',
#  'writeFitsWithOptions',
#  'x0',
#  'y0']

# %% [markdown]
# The `calexp` also contains a higher level `MaskedImage` object, which combines both the pixel values and the integer mask assigned to them.

# %%
calexp.maskedImage
# Out:
# lsst.afw.image.maskedImage.MaskedImageF=(image=[[-3.82834053e+01  3.42491035e+01  6.89195404e+01 ...  1.07490247e+03
#    1.04379651e+03  6.83699646e+02]
#  [-1.53812799e+01  6.62068939e+01  1.01078018e+02 ...  2.17995459e+03
#    1.68644275e+03  1.12186377e+03]
#  [ 1.56634842e+02  5.89559097e+01  4.05811920e+01 ...  4.90955322e+03
#    3.62566113e+03  2.37405029e+03]
#  ...
#  [ 1.14947586e+02  1.90423889e+02  3.01270084e+01 ...  1.50209183e+02
#   -8.01385345e+01 -5.34359436e+01]
#  [ 9.62147808e+00 -2.51698074e+01 -8.81778793e+01 ...  5.51945419e+01
#    3.44382763e-01  1.23965187e+02]
#  [ 2.03337059e+01  4.38427010e+01  6.95885391e+01 ...  9.42831573e+01
#   -1.12728176e+01 -8.36537323e+01]],
# mask=[[16 16 16 ... 16 16 16]
#  [16 16 16 ... 16 16 16]
#  [16 16 16 ... 16 16 16]
#  ...
#  [16 16 16 ... 16 16 16]
#  [16 16 16 ... 16 16 16]
#  [16 16 16 ... 16 16 16]], maskPlaneDict={'BAD': 0, 'BRIGHT_OBJECT': 12, 'CLIPPED': 13, 'CR': 3, 'CROSSTALK': 9, 'DETECTED': 5, 'DETECTED_NEGATIVE': 6, 'EDGE': 4, 'INEXACT_PSF': 14, 'INTRP': 2, 'NOT_DEBLENDED': 10, 'NO_DATA': 8, 'REJECTED': 15, 'SAT': 1, 'SENSOR_EDGE': 16, 'SUSPECT': 7, 'UNMASKEDNAN': 11}
# variance=[[ 5529.8726  5616.9614  5663.55   ...  7108.845   7062.105   6559.281 ]
#  [ 5539.506   5639.5845  5674.253  ...  8651.88    7942.262   7168.338 ]
#  [ 5778.256   5615.1196  5582.3257 ... 12574.483  10736.043   8967.241 ]
#  ...
#  [ 5710.0347  5800.673   5565.193  ...  5733.3804  5399.7476  5452.684 ]
#  [ 5573.488   5500.1426  5415.214  ...  5601.809   5520.49    5716.0107]
#  [ 5618.0747  5623.8003  5654.6514 ...  5682.6187  5546.012   5448.185 ]], bbox=(minimum=(0, 0), maximum=(4071, 3999)))

# %% [markdown]
# The `MaskedImage` can also be plotted directly by lsst.afw.display. More information can be found in the StackClub notebook on afw.display.

# %% [markdown]
# Access the variance object and the underlying Numpy array

# %%
calexp.variance
# Out:
# lsst.afw.image.image.ImageF=[[ 5529.8726  5616.9614  5663.55   ...  7108.845   7062.105   6559.281 ]
#  [ 5539.506   5639.5845  5674.253  ...  8651.88    7942.262   7168.338 ]
#  [ 5778.256   5615.1196  5582.3257 ... 12574.483  10736.043   8967.241 ]
#  ...
#  [ 5710.0347  5800.673   5565.193  ...  5733.3804  5399.7476  5452.684 ]
#  [ 5573.488   5500.1426  5415.214  ...  5601.809   5520.49    5716.0107]
#  [ 5618.0747  5623.8003  5654.6514 ...  5682.6187  5546.012   5448.185 ]], bbox=(minimum=(0, 0), maximum=(4071, 3999))

# %%
calexp.variance.array
# Out:
# array([[ 5529.8726,  5616.9614,  5663.55  , ...,  7108.845 ,  7062.105 ,
#          6559.281 ],
#        [ 5539.506 ,  5639.5845,  5674.253 , ...,  8651.88  ,  7942.262 ,
#          7168.338 ],
#        [ 5778.256 ,  5615.1196,  5582.3257, ..., 12574.483 , 10736.043 ,
#          8967.241 ],
#        ...,
#        [ 5710.0347,  5800.673 ,  5565.193 , ...,  5733.3804,  5399.7476,
#          5452.684 ],
#        [ 5573.488 ,  5500.1426,  5415.214 , ...,  5601.809 ,  5520.49  ,
#          5716.0107],
#        [ 5618.0747,  5623.8003,  5654.6514, ...,  5682.6187,  5546.012 ,
#          5448.185 ]], dtype=float32)

# %% [markdown]
# Access the mask and its underlying array

# %%
calexp.mask
# Out:
# lsst.afw.image.image.MaskX=[[16 16 16 ... 16 16 16]
#  [16 16 16 ... 16 16 16]
#  [16 16 16 ... 16 16 16]
#  ...
#  [16 16 16 ... 16 16 16]
#  [16 16 16 ... 16 16 16]
#  [16 16 16 ... 16 16 16]], bbox=(minimum=(0, 0), maximum=(4071, 3999)), maskPlaneDict={'BAD': 0, 'BRIGHT_OBJECT': 12, 'CLIPPED': 13, 'CR': 3, 'CROSSTALK': 9, 'DETECTED': 5, 'DETECTED_NEGATIVE': 6, 'EDGE': 4, 'INEXACT_PSF': 14, 'INTRP': 2, 'NOT_DEBLENDED': 10, 'NO_DATA': 8, 'REJECTED': 15, 'SAT': 1, 'SENSOR_EDGE': 16, 'SUSPECT': 7, 'UNMASKEDNAN': 11}

# %%
calexp.mask.array
# Out:
# array([[16, 16, 16, ..., 16, 16, 16],
#        [16, 16, 16, ..., 16, 16, 16],
#        [16, 16, 16, ..., 16, 16, 16],
#        ...,
#        [16, 16, 16, ..., 16, 16, 16],
#        [16, 16, 16, ..., 16, 16, 16],
#        [16, 16, 16, ..., 16, 16, 16]], dtype=int32)

# %% [markdown]
# Get the dimensions of the image, mask and variance

# %%
calexp.getDimensions()
# Out:
# Extent2I(4072, 4000)

# %% [markdown]
# The image, maskedImage and Exposure objects in `lsst.afw.display` include information on **LSST pixels**, which are 0-based with an optional offset.
#
# For a calexp these are usually zero.

# %%
calexp.getXY0()
# Out:
# Point2I(0, 0)

# %%
calexp.getX0(), calexp.getY0()
# Out:
# (0, 0)

# %% [markdown]
# ## Metadata

# %% [markdown]
# Access the wcs object

# %%
wcs = calexp.getWcs()
wcs
# Out:
# FITS standard SkyWcs:
# Sky Origin: (71.4150487209, -30.4874715969)
# Pixel Origin: (1997.09, 1911.19)
# Pixel Scale: 0.199747 arcsec/pixel

# %% [markdown]
# The WCS object can be used e.g. to convert pixel coordinates into sky coordinates

# %%
wcs.pixelToSky(100.0, 100.0)
# Out:
# SpherePoint(71.27171690184767*degrees, -30.410640494775688*degrees)

# %% [markdown]
# Let's try accessing the metadata, and see what (header) keywords we have.

# %%
metadata = calexp.getMetadata()
pprint(metadata.toDict())
# Out:
# {'AIRMASS': 1.07580229576959,
#  'AMEND': 1.0769458813073,
#  'AMSTART': 1.07580229576959,
#  'AP_ORDER': 3,
#  'A_ORDER': 2,
#  'BGMEAN': 3817.86814754402,
#  'BGVAR': 1.21432919434056,
#  'BP_ORDER': 3,
#  'B_ORDER': 2,
#  'CHIPID': 'R20_S11',
#  'COLORTERM1': 0.0,
#  'COLORTERM2': 0.0,
#  'COLORTERM3': 0.0,
#  'CR_SEED': '2135007486',
#  'EXPINFO_V': 1,
#  'FILTER': 'i',
#  'GAUSFWHM': 0.4,
#  'HAEND': 26.2128523945386,
#  'HASTART': 26.0875118154903,
#  'IMSIMVER': 'v0.6.1',
#  'INSTRUME': 'CAMERA',
#  'ISR_OSCAN_LEVELC00': 999.591792656587,
#  'ISR_OSCAN_LEVELC01': 999.622240172321,
#  'ISR_OSCAN_LEVELC02': 999.561769616027,
#  'ISR_OSCAN_LEVELC03': 999.511755057408,
#  'ISR_OSCAN_LEVELC04': 999.567079741379,
#  'ISR_OSCAN_LEVELC05': 999.559271343121,
#  'ISR_OSCAN_LEVELC06': 999.587752355316,
#  'ISR_OSCAN_LEVELC07': 999.519493177388,
#  'ISR_OSCAN_LEVELC10': 999.561030383091,
#  'ISR_OSCAN_LEVELC11': 999.579004329004,
#  'ISR_OSCAN_LEVELC12': 999.528475711893,
#  'ISR_OSCAN_LEVELC13': 999.638504155125,
#  'ISR_OSCAN_LEVELC14': 999.522670721592,
#  'ISR_OSCAN_LEVELC15': 999.521097046414,
#  'ISR_OSCAN_LEVELC16': 999.558983419407,
#  'ISR_OSCAN_LEVELC17': 999.553888888889,
#  'ISR_OSCAN_SIGMAC00': 0.0,
#  'ISR_OSCAN_SIGMAC01': 0.0,
#  'ISR_OSCAN_SIGMAC02': 0.0,
#  'ISR_OSCAN_SIGMAC03': 0.0,
#  'ISR_OSCAN_SIGMAC04': 0.0,
#  'ISR_OSCAN_SIGMAC05': 0.0,
#  'ISR_OSCAN_SIGMAC06': 0.0,
#  'ISR_OSCAN_SIGMAC07': 0.0,
#  'ISR_OSCAN_SIGMAC10': 0.0,
#  'ISR_OSCAN_SIGMAC11': 0.0,
#  'ISR_OSCAN_SIGMAC12': 0.0,
#  'ISR_OSCAN_SIGMAC13': 0.0,
#  'ISR_OSCAN_SIGMAC14': 0.0,
#  'ISR_OSCAN_SIGMAC15': 0.0,
#  'ISR_OSCAN_SIGMAC16': 0.0,
#  'ISR_OSCAN_SIGMAC17': 0.0,
#  'MAGZERO_NOBJ': 55,
#  'MAGZERO_RMS': 0.000288300203731377,
#  'MONOWL': -1,
#  'OBSGEO-X': 1818939.05374054,
#  'OBSGEO-Y': -5208471.267364,
#  'OBSGEO-Z': -3195171.50942422,
#  'ORIGIN': 'IMSIM',
#  'OVERSCAN': 'Overscan corrected',
#  'PKG00000': 'lsst_sims',
#  'PKG00001': 'throughputs',
#  'PKG00002': 'sims_skybrightness_data',
#  'RN_SEED': 4048972475,
#  'SIMULATE': True,
#  'TAG00000': 'sims_w_2019_42',
#  'TELESCOP': 'LSST',
#  'TESTTYPE': 'IMSIM',
#  'TFORM1': '1PB(14884)',
#  'TTYPE1': 'COMPRESSED_DATA',
#  'VER00001': '1.4',
#  'VER00002': '2017.05.05'}

# %%
#metadata.get('CCDTEMP')
metadata.get('TELESCOP')
# Out:
# 'LSST'

# %% [markdown]
# ## Better metadata: ExposureInfo and VisitInfo

# %% [markdown]
# For many purposes, information about an exposure is obtainable via the ExposureInfo and VisitInfo classes.

# %%
calexp_info = calexp.getInfo()

# %%
visit_info = calexp_info.getVisitInfo()

# %%
[m for m in dir(visit_info) if not m.startswith('_')]
# Out:
# ['boresightAirmass',
#  'boresightAzAlt',
#  'boresightHourAngle',
#  'boresightParAngle',
#  'boresightRaDec',
#  'boresightRotAngle',
#  'darkTime',
#  'date',
#  'era',
#  'exposureTime',
#  'focusZ',
#  'getBoresightAirmass',
#  'getBoresightAzAlt',
#  'getBoresightHourAngle',
#  'getBoresightParAngle',
#  'getBoresightRaDec',
#  'getBoresightRotAngle',
#  'getDarkTime',
#  'getDate',
#  'getEra',
#  'getExposureId',
#  'getExposureTime',
#  'getFocusZ',
#  'getHasSimulatedContent',
#  'getId',
#  'getInstrumentLabel',
#  'getLocalEra',
#  'getObject',
#  'getObservationReason',
#  'getObservationType',
#  'getObservatory',
#  'getRotType',
#  'getScienceProgram',
#  'getUt1',
#  'getWeather',
#  'hasSimulatedContent',
#  'id',
#  'instrumentLabel',
#  'isPersistable',
#  'localEra',
#  'object',
#  'observationReason',
#  'observationType',
#  'observatory',
#  'readFits',
#  'rotType',
#  'scienceProgram',
#  'ut1',
#  'weather',
#  'writeFits']

# %% [markdown]
# Obtain weather information for this visit

# %%
visit_info.getWeather()
# Out:
# Weather(nan, nan, 40)

# %% [markdown]
# Check if this calexp has a valid polygon.

# %%
calexp_info.hasValidPolygon()
# Out:
# False

# %% [markdown]
# There is no valid polygon for the `calexp`; so the `polygon` variable in the next cell returns `None`.

# %%
polygon = calexp_info.getValidPolygon()
print(polygon)
# Out:
# None

# %% [markdown]
# The calexp is not a coadd so this method returns False.

# %%
calexp_info.hasCoaddInputs()
# Out:
# False

# %% [markdown]
# Does the calexp contain transmission curve information?

# %%
calexp_info.hasTransmissionCurve()
# Out:
# False

# %% [markdown]
# Does the calexp contain a World Coordinate System?

# %%
calexp_info.hasWcs()
# Out:
# True

# %% [markdown]
# Does the calexp have a detector?

# %%
calexp_info.hasDetector()
# Out:
# True

# %%
[m for m in dir(calexp_info.getDetector()) if not m.startswith('_')]
# Out:
# ['Builder',
#  'InCameraBuilder',
#  'PartialRebuilder',
#  'fromConfig',
#  'getAmplifiers',
#  'getBBox',
#  'getCenter',
#  'getCorners',
#  'getCrosstalk',
#  'getId',
#  'getName',
#  'getNativeCoordSys',
#  'getOrientation',
#  'getPhysicalType',
#  'getPixelSize',
#  'getSerial',
#  'getTransform',
#  'getTransformMap',
#  'getType',
#  'hasCrosstalk',
#  'hasTransform',
#  'isPersistable',
#  'makeCameraSys',
#  'readFits',
#  'rebuild',
#  'transform',
#  'writeFits']

# %% [markdown]
# Does the calexp have an aperture correction map?

# %%
calexp_info.hasApCorrMap()
# Out:
# True

# %% [markdown]
# Let's get the aperture correction map and print some information about it

# %%
apCorrMap = calexp_info.getApCorrMap()

# %%
for k in apCorrMap.keys():
    print(k, apCorrMap.get(k))
# Out:
# base_GaussianFlux_instFlux ChebyshevBoundedField ((3,3,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# base_GaussianFlux_instFluxErr ChebyshevBoundedField ((1,1,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# base_PsfFlux_instFlux ChebyshevBoundedField ((3,3,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# base_PsfFlux_instFluxErr ChebyshevBoundedField ((1,1,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# ext_convolved_ConvolvedFlux_0_3_3_instFlux ChebyshevBoundedField ((3,3,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# ext_convolved_ConvolvedFlux_0_3_3_instFluxErr ChebyshevBoundedField ((1,1,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# ext_convolved_ConvolvedFlux_0_4_5_instFlux ChebyshevBoundedField ((3,3,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# ext_convolved_ConvolvedFlux_0_4_5_instFluxErr ChebyshevBoundedField ((1,1,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# ext_convolved_ConvolvedFlux_0_6_0_instFlux ChebyshevBoundedField ((3,3,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# ext_convolved_ConvolvedFlux_0_6_0_instFluxErr ChebyshevBoundedField ((1,1,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# ext_convolved_ConvolvedFlux_0_kron_instFlux ChebyshevBoundedField ((3,3,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# ext_convolved_ConvolvedFlux_0_kron_instFluxErr ChebyshevBoundedField ((1,1,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# ext_convolved_ConvolvedFlux_1_3_3_instFlux ChebyshevBoundedField ((3,3,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# ext_convolved_ConvolvedFlux_1_3_3_instFluxErr ChebyshevBoundedField ((1,1,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# ext_convolved_ConvolvedFlux_1_4_5_instFlux ChebyshevBoundedField ((3,3,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# ext_convolved_ConvolvedFlux_1_4_5_instFluxErr ChebyshevBoundedField ((1,1,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# ext_convolved_ConvolvedFlux_1_6_0_instFlux ChebyshevBoundedField ((3,3,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# ext_convolved_ConvolvedFlux_1_6_0_instFluxErr ChebyshevBoundedField ((1,1,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# ext_convolved_ConvolvedFlux_1_kron_instFlux ChebyshevBoundedField ((3,3,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# ext_convolved_ConvolvedFlux_1_kron_instFluxErr ChebyshevBoundedField ((1,1,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# ext_convolved_ConvolvedFlux_2_3_3_instFlux ChebyshevBoundedField ((3,3,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# ext_convolved_ConvolvedFlux_2_3_3_instFluxErr ChebyshevBoundedField ((1,1,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# ext_convolved_ConvolvedFlux_2_4_5_instFlux ChebyshevBoundedField ((3,3,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# ext_convolved_ConvolvedFlux_2_4_5_instFluxErr ChebyshevBoundedField ((1,1,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# ext_convolved_ConvolvedFlux_2_6_0_instFlux ChebyshevBoundedField ((3,3,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# ext_convolved_ConvolvedFlux_2_6_0_instFluxErr ChebyshevBoundedField ((1,1,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# ext_convolved_ConvolvedFlux_2_kron_instFlux ChebyshevBoundedField ((3,3,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# ext_convolved_ConvolvedFlux_2_kron_instFluxErr ChebyshevBoundedField ((1,1,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# ext_convolved_ConvolvedFlux_3_3_3_instFlux ChebyshevBoundedField ((3,3,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# ext_convolved_ConvolvedFlux_3_3_3_instFluxErr ChebyshevBoundedField ((1,1,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# ext_convolved_ConvolvedFlux_3_4_5_instFlux ChebyshevBoundedField ((3,3,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# ext_convolved_ConvolvedFlux_3_4_5_instFluxErr ChebyshevBoundedField ((1,1,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# ext_convolved_ConvolvedFlux_3_6_0_instFlux ChebyshevBoundedField ((3,3,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# ext_convolved_ConvolvedFlux_3_6_0_instFluxErr ChebyshevBoundedField ((1,1,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# ext_convolved_ConvolvedFlux_3_kron_instFlux ChebyshevBoundedField ((3,3,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# ext_convolved_ConvolvedFlux_3_kron_instFluxErr ChebyshevBoundedField ((1,1,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# ext_photometryKron_KronFlux_instFlux ChebyshevBoundedField ((3,3,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# ext_photometryKron_KronFlux_instFluxErr ChebyshevBoundedField ((1,1,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# modelfit_CModel_dev_instFlux ChebyshevBoundedField ((3,3,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# modelfit_CModel_dev_instFluxErr ChebyshevBoundedField ((1,1,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# modelfit_CModel_exp_instFlux ChebyshevBoundedField ((3,3,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# modelfit_CModel_exp_instFluxErr ChebyshevBoundedField ((1,1,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# modelfit_CModel_initial_instFlux ChebyshevBoundedField ((3,3,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# modelfit_CModel_initial_instFluxErr ChebyshevBoundedField ((1,1,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# modelfit_CModel_instFlux ChebyshevBoundedField ((3,3,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))
# modelfit_CModel_instFluxErr ChebyshevBoundedField ((1,1,) coefficients in y,x) on Box2I(Point2I(0, 0), Extent2I(4072, 4000))

# %% [markdown]
# ## Image PSF

# %% [markdown]
# Check if our calexp has a PSF

# %%
calexp.hasPsf()
# Out:
# True

# %%
psf = calexp.getPsf()

# %% [markdown]
# The PSF object can be used to get a realization of a PSF at a specific point

# %%
from lsst.geom import PointD
psfimage = psf.computeImage(PointD(100.,100.))

# %% [markdown]
# Visualize the PSF

# %%
display = afwDisplay.Display()
display.scale('asinh', min=0.0, max=1.e-3, unit='absolute')
display.mtv(psfimage)

# %% [markdown]
# Access the calibration object which can be used to convert instrumental magnitudes to AB magnitudes

# %%
calib = calexp.getPhotoCalib()
calib
# Out:
# PhotoCalib(spatially constant with mean: 0.660685 error: 0.000175435)

# %% [markdown]
# ## Image cutouts

# %% [markdown]
# We can make a cutout from the calexp in our session.

# %%
import lsst.geom      as afwGeom
import lsst.afw.image as afwImage

# %%
bbox = afwGeom.Box2I()
bbox.include(afwGeom.Point2I(1050,2700))
bbox.include(afwGeom.Point2I(1150,2800))

cutout = calexp[bbox]

# %% [markdown]
# Notice that when the image is displayed, the pixel values relate to the parent image.

# %%
display = afwDisplay.Display()
display.scale('asinh', 'zscale')
display.mtv(cutout.image)

# %% [markdown]
# The coordinate of the lower-left-hand pixel is XY0.

# %%
cutout.getXY0()
# Out:
# Point2I(1050, 2700)

# %% [markdown]
# If a cutout was all that was desired from the start, we could have used our BoundingBox together with our Butler to have read in only the cutout.

# %%
cutout_calexp = butler.get('calexp', parameters={'bbox':bbox}, dataId=dataId)
cutout_calexp.getDimensions()
# Out:
# /opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-4.1.0/Linux64/obs_base/g188f660963+e1f1daa193/python/lsst/obs/base/formatters/fitsExposure.py:644: UserWarning: Data ID {instrument: 'LSSTCam-imSim', detector: 76, visit: 512055} is missing (implied) value(s) for ['band', 'physical_filter']; the correctness of this Exposure's FilterLabel cannot be guaranteed. Call Registry.expandDataId before Butler.get to avoid this.
#   warnings.warn(
# Extent2I(201, 201)

# %%
display = afwDisplay.Display()
display.scale('asinh', 'zscale')
display.mtv(cutout_calexp.image)

# %% [markdown]
# The `clone` method makes a deep copy. The result can be sliced with a BoundingBox

# %%
clone_cutout = calexp.clone()[bbox]

# %%
display = afwDisplay.Display()
display.scale("asinh", "zscale")
display.mtv(clone_cutout.image)

# %% [markdown]
# ## Repeat for a coadd

# %% [markdown]
# For this last section, we will look at a coadd image. Earlier, we used the Butler to retrieve both calexp and coadd images.  Let's see here what methods it provides:

# %%
coadd_methods = [m for m in dir(coadd) if not m.startswith('_')]

# %%
coadd_methods
# Out:
# ['Factory',
#  'clone',
#  'containsSkyCoords',
#  'convertD',
#  'convertF',
#  'convex_polygon',
#  'detector',
#  'dtype',
#  'filter',
#  'filterLabel',
#  'getBBox',
#  'getConvexPolygon',
#  'getCutout',
#  'getDetector',
#  'getDimensions',
#  'getFilter',
#  'getFilterLabel',
#  'getHeight',
#  'getImage',
#  'getInfo',
#  'getMask',
#  'getMaskedImage',
#  'getMetadata',
#  'getPhotoCalib',
#  'getPsf',
#  'getVariance',
#  'getWcs',
#  'getWidth',
#  'getX0',
#  'getXY0',
#  'getY0',
#  'hasPsf',
#  'hasWcs',
#  'height',
#  'image',
#  'info',
#  'mask',
#  'maskedImage',
#  'photoCalib',
#  'psf',
#  'readFits',
#  'readFitsWithOptions',
#  'setDetector',
#  'setFilter',
#  'setFilterLabel',
#  'setImage',
#  'setInfo',
#  'setMask',
#  'setMaskedImage',
#  'setMetadata',
#  'setPhotoCalib',
#  'setPsf',
#  'setVariance',
#  'setWcs',
#  'setXY0',
#  'subset',
#  'variance',
#  'visitInfo',
#  'wcs',
#  'width',
#  'writeFits',
#  'writeFitsWithOptions',
#  'x0',
#  'y0']

# %%
set(coadd_methods).symmetric_difference(set(calexp_methods))
# Out:
# set()

# %% [markdown]
# The result of the `set` command above shows that a calexp and a coadd have the same methods. This is expected, because they are instances of the same class (`ExposureF`).

# %%
print(f"calexp class: {calexp.__class__}")
print(f"coadd  class: {coadd.__class__}")
# Out:
# calexp class: <class 'lsst.afw.image.exposure.ExposureF'>
# coadd  class: <class 'lsst.afw.image.exposure.ExposureF'>

# %% [markdown]
# A `deepCoadd` and a visit `calexp` differ mainly in the masks, xy0 values, and depth.

# %%
print(f"calexp XY0: {calexp.getXY0()}")
calexp.mask.getMaskPlaneDict()
# Out:
# calexp XY0: (0, 0)
# {'BAD': 0,
#  'BRIGHT_OBJECT': 12,
#  'CLIPPED': 13,
#  'CR': 3,
#  'CROSSTALK': 9,
#  'DETECTED': 5,
#  'DETECTED_NEGATIVE': 6,
#  'EDGE': 4,
#  'INEXACT_PSF': 14,
#  'INTRP': 2,
#  'NOT_DEBLENDED': 10,
#  'NO_DATA': 8,
#  'REJECTED': 15,
#  'SAT': 1,
#  'SENSOR_EDGE': 16,
#  'SUSPECT': 7,
#  'UNMASKEDNAN': 11}

# %%
print(f"coadd XY0: {coadd.getXY0()}")
coadd.mask.getMaskPlaneDict()
# Out:
# coadd XY0: (3900, 15900)
# {'BAD': 0,
#  'BRIGHT_OBJECT': 12,
#  'CLIPPED': 13,
#  'CR': 3,
#  'CROSSTALK': 9,
#  'DETECTED': 5,
#  'DETECTED_NEGATIVE': 6,
#  'EDGE': 4,
#  'INEXACT_PSF': 14,
#  'INTRP': 2,
#  'NOT_DEBLENDED': 10,
#  'NO_DATA': 8,
#  'REJECTED': 15,
#  'SAT': 1,
#  'SENSOR_EDGE': 16,
#  'SUSPECT': 7,
#  'UNMASKEDNAN': 11}

# %% [markdown]
# Display the coadd image

# %%
display = afwDisplay.Display()
display.scale("asinh", "zscale")
display.mtv(coadd.image)
